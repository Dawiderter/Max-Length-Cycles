# %%
import matplotlib.pyplot as plt 
import pandas as pd

# %matplotlib inline

# %% [markdown]
# Czytanie danych

# %%
data_num = pd.read_csv("cycles.csv")
data_max = pd.read_csv("maximums.csv")

# %% [markdown]
# Wartość oczekiwana liczby cykli

# %%
data_num.plot(x = "n", xlabel = "Długość permutacji", ylabel = "Liczba cykli", title = "Średnie liczby cykli", alpha = 0.6)
# Out:
# <AxesSubplot:title={'center':'Średnie liczby cykli'}, xlabel='Długość permutacji', ylabel='Liczba cykli'>

# %% [markdown]
# Wartośc oczekiwana
# największej długości cyklu

# %%
data_max.plot(x = "n", xlabel = "Długość permutacji", ylabel = "Długość cykli", title = "Maksymalne długości cykli", alpha = 0.6)
# Out:
# <AxesSubplot:title={'center':'Maksymalne długości cykli'}, xlabel='Długość permutacji', ylabel='Długość cykli'>
